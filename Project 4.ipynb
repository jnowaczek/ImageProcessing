# %%
from sympy import *
import imageio
import numpy as np
import math
import matplotlib.pyplot as plt
import scipy.misc as misc
import scipy.ndimage as ndi

# %%
plt.style.use(['seaborn-poster', {'axes.grid': False, 'image.cmap' : 'Greys_r'}])

# %% [markdown]
# ## Question 1

# %% [markdown]
# ## Question 2

# %%
original = misc.ascent()
plt.imshow(original)
plt.show()

# %%
noise = np.zeros((512, 512))

# %%
t, x, y = symbols('t, x, y')
def x0(t):
    return t * a
def y0(t):
    return t * 2 * b
def f(x, y):
    return original[x][y]
def g(x, y):
    return integrate(f(x - x0(t), y - y0(t)), (t, 0, 2 * T))
def eta(x, y):
    return
# Out:
#   File "<ipython-input-26-37752e7d2dfa>", line 4
#     def f(x, y):
#       ^
# IndentationError: expected an indented block
